# %% [markdown]
# Dominik Czyżyk
# 401858
# grupa: 2a

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Zadanie 3

# %%
# Zdefiniowanie funkcji
def f(x):
    return x**2 + 5

# %%
# Przygotowanie trzech zestawów argumentów
x_1 = np.linspace(-1, 1)
x_2 = np.linspace(-6, 6)
x_3 = np.linspace(0, 5)

# Wyrysowanie wykresów zdefiniowanej wyżej funkcji dla różnych zestawów argumentów
plt.figure()
plt.plot(x_1, f(x_1), label='x^2 + 5')
plt.title("Wykres funkcji x^2 + 5 na przedziale [-1, 1]")
plt.xlabel("oś x")
plt.ylabel("oś y")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_2, f(x_2), label='x^2 + 5')
plt.title("Wykres funkcji x^2 + 5 na przedziale [-6, 6]")
plt.xlabel("oś x")
plt.ylabel("oś y")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(x_3, f(x_3), label='x^2 + 5')
plt.title("Wykres funkcji x^2 + 5 na przedziale [0, 5]")
plt.xlabel("oś x")
plt.ylabel("oś y")
plt.legend()
plt.show()

# %% [markdown]
# # Zadanie 4

# %%
# Stworzenie dataframe
d = {'name': ['Aleksandra', 'Bartosz', 'Bartłomiej', 'Dominik', 'Mateusz'], 'surname': ['Lis', 'Więcek', 'Więcek', 'Czyżyk', 'Kowalski'], 'age': [20, 21, 21, 20, 21], 'sex': ['f', 'm', 'm', 'm', 'm']}
df = pd.DataFrame(data=d)
df
# Out:
#          name   surname  age sex
# 0  Aleksandra       Lis   20   f
# 1     Bartosz    Więcek   21   m
# 2  Bartłomiej    Więcek   21   m
# 3     Dominik    Czyżyk   20   m
# 4     Mateusz  Kowalski   21   m

# %%
# Informcje o danych
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 164.0+ bytes

# %%
# Opis danych 
df.describe()
# Out:
#              age
# count   5.000000
# mean   20.600000
# std     0.547723
# min    20.000000
# 25%    20.000000
# 50%    21.000000
# 75%    21.000000
# max    21.000000

# %%
# Wypisanie pierwszych trzech rekordów
df.head(3)
# Out:
#          name surname  age sex
# 0  Aleksandra     Lis   20   f
# 1     Bartosz  Więcek   21   m
# 2  Bartłomiej  Więcek   21   m
